# %%
import pandas as pd
import os

# %% [markdown]
# # Step 1 Merging all months data into one single dataset

# %%
files = [file for file in os.listdir('Sales_Data.csv')]
all_months = pd.DataFrame()
for file in files:
    df = pd.read_csv('Sales_Data'+file)
    all_months = pd.concat([all_months,df])
    
all_months.to_csv("all_data.csv", index = False)

# %% [markdown]
# # Read dataframe

# %%
df = pd.read_csv("all_data.csv")
df.head(3)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
#
#        Order Date                   Purchase Address
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001
# 1             NaN                                NaN
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Drop row NAN

# %%
nan_df = df[df.isna().any(axis=1)]
display(nan_df.head())
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN

# %%
df = df.dropna(how='all') 
#Droping all NAN , 
#how =any--will drop row if it have single any also
#all =any--will drop all row 
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# # Drop row of NAN

# %%
nan_df = df[df.isna().any(axis=1)]
nan_df.head(10)
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address, Month]
# Index: []

# %% [markdown]
# Augment data with additional columns

# %% [markdown]
# # Task 2: Add month columns

# %%
df['Month'] = df['Order Date'].str[0:2]
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %% [markdown]
# Get rid of text in order data column

# %% [markdown]
# Find or if any

# %%
df = df[df['Order Date'].str[0:2]!='Or']
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %%
df['Month'] = df['Order Date'].str[0:2]
df['Month'] = df['Month'].astype('int32')
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# # Question 1: What was the best month for sales? How much was earned that month?

# %%
#Convert column to correct type(float to number)
df['Quantity Ordered']=pd.to_numeric(df['Quantity Ordered'])
df['Price Each']=pd.to_numeric(df['Price Each'])

# %%
df['Sales'] = df['Quantity Ordered'] + df['Price Each']
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   13.95
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4  100.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  601.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   12.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   12.99

# %%
result=df.groupby('Month').sum()

# %%
#Plotting 
import matplotlib.pyplot as plt
months = range(1,13)
plt.bar(months, result['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD')
plt.show()

# %% [markdown]
# # Which city have highest number of sales?

# %% [markdown]
# Add city column

# %%
## Using .apply()-- Aplly is used to apply function on whole dataset
#lambda -- for x in x -perform condition
df['Column'] = df['Purchase Address'].apply(lambda x:x.split(',')[1])
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   13.95
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4  100.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  601.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   12.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   12.99
#
#          Column
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %%
# Using Function

def get_city(address):
    return address.split(',')[1]

def get_state(address):
    return address.split(',')[2].split(' ')[1]

df['city'] = df['Purchase Address'].apply(lambda x: f"{get_city(x)} ({get_state(x)})")
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   13.95
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4  100.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  601.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   12.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   12.99
#
#            Column               city
# 0        DallasTX        Dallas (TX)
# 2        BostonMA        Boston (MA)
# ...

# %%
results=df.groupby('city').sum()
results
# Out:
#                      Quantity Ordered  Price Each   Month       Sales
# city
#  Atlanta (GA)                   16602  2779908.20  104794  2796510.20
#  Austin (TX)                    11153  1809873.61   69829  1821026.61
#  Boston (MA)                    22528  3637409.77  141112  3659937.77
#  Dallas (TX)                    16730  2752627.82  104620  2769357.82
#  Los Angeles (CA)               33289  5421435.23  208325  5454724.23
#  New York City (NY)             27932  4635370.83  175741  4663302.83
#  Portland (ME)                   2750   447189.25   17144   449939.25
#  Portland (OR)                  11303  1860558.22   70621  1871861.22
#  San Francisco (CA)             50239  8211461.74  315520  8261700.74
#  Seattle (WA)                   16553  2733296.01  104941  2749849.01

# %%
#Plotting 
cities = df['city'].unique()
plt.bar(cities, results['Sales'])
plt.xticks(cities, rotation = 'vertical', size =8) #Changing orientation of x label
plt.ylabel('Sales in USD')
plt.xlabel('Month Match')

plt.show()

# %% [markdown]
# # Above plot is having issue, as sales and city is having different order

# %%
cities = [city for city, df in df.groupby('city')] ## taking city value in sales order
plt.bar(cities, results['Sales'])
plt.xticks(cities, rotation = 'vertical', size =8) #Changing orientation of x label
plt.ylabel('Sales in USD')
plt.xlabel('Month Match')

plt.show()

# %% [markdown]
# # Question 3: What time should we display advertisements to maximize likelihood of coustomer's buying product?

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   13.95
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4  100.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  601.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   12.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   12.99
#
#            Column               city
# 0        DallasTX        Dallas (TX)
# ...

# %%
df['Hour'] = df['Order Date'].dt.hour
df['Minute'] = df['Order Date'].dt.minute
df['Minute'] = df['Order Date'].dt.minute
df.head(3)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   13.95
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4  100.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  601.00
#
#            Column               city  Hour  Minute
# 0        DallasTX        Dallas (TX)     8      46
# 2        BostonMA        Boston (MA)    22      30
# 3   Los AngelesCA   Los Angeles (CA)    14      38

# %%
hours = [hour for hour, df in df.groupby('Hour')] ## taking city value in sales order
plt.plot(hours, df.groupby(['Hour']).count())
plt.xticks(hours)
plt.ylabel('Number of orders')
plt.xlabel('Hour')
plt.grid()
plt.show()
